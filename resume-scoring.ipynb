# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
list.files("/kaggle/input/")
# Out:
# [1] "resumescore"

# %%
# Install necessary packages if not already installed
if (!require("pdftools")) {
  install.packages("pdftools")
  library(pdftools)
}

if (!require("tm")) {
  install.packages("tm")
  library(tm)
}

if (!require("textTinyR")) {
  install.packages("textTinyR")
  library(textTinyR)
}

# Function to preprocess text (remove stopwords, punctuation, etc.)
preprocess_text <- function(text) {
  text <- tolower(text)  # Convert to lowercase
  text <- removePunctuation(text)  # Remove punctuation
  text <- removeNumbers(text)  # Remove numbers
  text <- removeWords(text, stopwords("en"))  # Remove stopwords
  text <- stripWhitespace(text)  # Remove extra whitespaces
  return(text)
}

# Function to extract text from the resume PDF
extract_resume_text <- function(resume_file) {
  resume_text <- pdf_text(resume_file)
  resume_text <- paste(resume_text, collapse = " ")  # Combine all pages into one string
  return(resume_text)
}

# Example job description
job_description <- "Data Scientist needed with skills in Python, Machine Learning, and Deep Learning.
Must have experience in developing predictive models, working with large datasets, and using data visualization tools."

# Preprocess the job description
job_description_clean <- preprocess_text(job_description)

# Ensure the resume file path is correctly updated in Kaggle
resume_file <- "/kaggle/input/resumescore/prekshareddykasam-1.pdf"  # Updated file path

# Extract text from the resume PDF
resume_text <- extract_resume_text(resume_file)

# Preprocess the resume text
resume_text_clean <- preprocess_text(resume_text)

# Print the cleaned resume text for verification (optional)
print("Cleaned Resume Text:")
print(resume_text_clean)

# Use textTinyR's COS_TEXT to compute the cosine similarity
similarity_score <- COS_TEXT(text_vector1 = job_description_clean, text_vector2 = resume_text_clean)

# Convert similarity score to percentage
similarity_score_percentage <- similarity_score * 100

# Output the similarity score
print(paste("Resume Score:", round(similarity_score_percentage, 2), "/10"))
# Out:
# [1] "Cleaned Resume Text:"
# [1] " preksha reddy kasam hyderabad ts prekshareddykasamgmailcom httpwwwlinkedincominprekshareddy education gokaraju rangaraju institute technology hyderabad ts anticipated graduation jul bachelor technology computer science business systems gpa coursework fundamentals computer science data structures algorithms objectoriented programming using c database management systems operating systems trividyaa junior college hyderabad ts may coursework mathematics physics chemistry gpa skills programming languages pythonc sql web technologies html css operating systems windows technical presentations student data management using c jan • developed student management system c efficient data handling • integrated database store student records login information • strong problemsolving skills demonstrated writing code development • collaborated mentors feedback guidance • received positive feedback clarity depth presentation technical projects online art gallery using html c jul • developed designed userfriendly registration signin art gallery add cart checkout web pages • applied modern css techniques create webpages • focused usercentric design principles enhance navigation user experience • guidance professor internet solved issues faced project • gained appreciations innovative coding ideas certifications • programming essentials c cisco dec • aws academy graduate cloud foundations mar • programming python internshala sep • devtalks google developer student club nov • introduction cybersecurity cisco nov leadership extracurricular student coordinator pragna gokaraju rangaraju institute technology nov • organized technical nontechnical events college annual fest • recruited trained student volunteers collaborate event planning execution • managed event expenses adhered allocated budget • utilized social media effectively market events generate interest among people "
# [1] "Resume Score: 9.49 /10"
